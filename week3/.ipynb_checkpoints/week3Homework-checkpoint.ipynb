# %% [markdown]
# # Week 3 homework.
#
# This notebook contains assignments for week 3 classifying car prices

# %%
## Import the modules needed for the analys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import seaborn as sns

# %matplotlib inline

# %% [markdown]
# ### Download and load the data
#
# Download the data and read it in using pandas

# %%
#!wget -O car_price.csv 'https://raw.githubusercontent.com/alexeygrigorev/mlbookcamp-code/master/chapter-02-car-price/data.csv'

# %%
## read in the data
df = pd.read_csv('car_price.csv')

# %%
## get the columns needed for the analysis
column_needed = [
'Make','Model','Year', 'Engine HP','Engine Cylinders',
'Transmission Type','Vehicle Style','highway MPG','city mpg','MSRP']

# %%
car_price_df = df[column_needed]

# %%
car_price_df
# Out:
#           Make       Model  Year  Engine HP  Engine Cylinders  \
# 0          BMW  1 Series M  2011      335.0               6.0
# 1          BMW    1 Series  2011      300.0               6.0
# 2          BMW    1 Series  2011      300.0               6.0
# 3          BMW    1 Series  2011      230.0               6.0
# 4          BMW    1 Series  2011      230.0               6.0
# ...        ...         ...   ...        ...               ...
# 11909    Acura         ZDX  2012      300.0               6.0
# 11910    Acura         ZDX  2012      300.0               6.0
# 11911    Acura         ZDX  2012      300.0               6.0
# 11912    Acura         ZDX  2013      300.0               6.0
# 11913  Lincoln      Zephyr  2006      221.0               6.0
#
#       Transmission Type  Vehicle Style  highway MPG  city mpg   MSRP
# 0                MANUAL          Coupe           26        19  46135
# 1                MANUAL    Convertible           28        19  40650
# 2                MANUAL          Coupe           28        20  36350
# 3                MANUAL          Coupe           28        18  29450
# 4                MANUAL    Convertible           28        18  34500
# ...                 ...            ...          ...       ...    ...
# 11909         AUTOMATIC  4dr Hatchback           23        16  46120
# 11910         AUTOMATIC  4dr Hatchback           23        16  56670
# 11911         AUTOMATIC  4dr Hatchback           23        16  50620
# 11912         AUTOMATIC  4dr Hatchback           23        16  50920
# 11913         AUTOMATIC          Sedan           26        17  28995
#
# [11914 rows x 10 columns]

# %%
 car_price_df.columns = car_price_df.columns.str.lower().str.replace(" ", "_")

# %%
car_price_df
# Out:
#           make       model  year  engine_hp  engine_cylinders  \
# 0          BMW  1 Series M  2011      335.0               6.0
# 1          BMW    1 Series  2011      300.0               6.0
# 2          BMW    1 Series  2011      300.0               6.0
# 3          BMW    1 Series  2011      230.0               6.0
# 4          BMW    1 Series  2011      230.0               6.0
# ...        ...         ...   ...        ...               ...
# 11909    Acura         ZDX  2012      300.0               6.0
# 11910    Acura         ZDX  2012      300.0               6.0
# 11911    Acura         ZDX  2012      300.0               6.0
# 11912    Acura         ZDX  2013      300.0               6.0
# 11913  Lincoln      Zephyr  2006      221.0               6.0
#
#       transmission_type  vehicle_style  highway_mpg  city_mpg   msrp
# 0                MANUAL          Coupe           26        19  46135
# 1                MANUAL    Convertible           28        19  40650
# 2                MANUAL          Coupe           28        20  36350
# 3                MANUAL          Coupe           28        18  29450
# 4                MANUAL    Convertible           28        18  34500
# ...                 ...            ...          ...       ...    ...
# 11909         AUTOMATIC  4dr Hatchback           23        16  46120
# 11910         AUTOMATIC  4dr Hatchback           23        16  56670
# 11911         AUTOMATIC  4dr Hatchback           23        16  50620
# 11912         AUTOMATIC  4dr Hatchback           23        16  50920
# 11913         AUTOMATIC          Sedan           26        17  28995
#
# [11914 rows x 10 columns]

# %%
car_price_df.isna().sum()
# Out:
# make                  0
# model                 0
# year                  0
# engine_hp            69
# engine_cylinders     30
# transmission_type     0
# vehicle_style         0
# highway_mpg           0
# city_mpg              0
# msrp                  0
# dtype: int64

# %%
## Replace
car_price_df = car_price_df.fillna(0)

# %%
car_price_df.isna().sum()
# Out:
# make                 0
# model                0
# year                 0
# engine_hp            0
# engine_cylinders     0
# transmission_type    0
# vehicle_style        0
# highway_mpg          0
# city_mpg             0
# msrp                 0
# dtype: int64

# %%
## Rename the columns
car_price_df.rename(columns = {'msrp':'price'}, inplace=True)

# %%
car_price_df.head()
# Out:
#   make       model  year  engine_hp  engine_cylinders transmission_type  \
# 0  BMW  1 Series M  2011      335.0               6.0            MANUAL
# 1  BMW    1 Series  2011      300.0               6.0            MANUAL
# 2  BMW    1 Series  2011      300.0               6.0            MANUAL
# 3  BMW    1 Series  2011      230.0               6.0            MANUAL
# 4  BMW    1 Series  2011      230.0               6.0            MANUAL
#
#   vehicle_style  highway_mpg  city_mpg  price
# 0         Coupe           26        19  46135
# 1   Convertible           28        19  40650
# 2         Coupe           28        20  36350
# 3         Coupe           28        18  29450
# 4   Convertible           28        18  34500

# %% [markdown]
# ## Question 1
#
#
# What is the most frequent observation (mode) for the column transmission_type?
#
#     AUTOMATIC
#     MANUAL
#     AUTOMATED_MANUAL
#     DIRECT_DRIVE

# %%
## Get the transmission_type and use value_counts() to count the number of occurance for each. 
car_price_df['transmission_type'].value_counts()
# Out:
# transmission_type
# AUTOMATIC           8266
# MANUAL              2935
# AUTOMATED_MANUAL     626
# DIRECT_DRIVE          68
# UNKNOWN               19
# Name: count, dtype: int64

# %%
## Can also be done using the groupby and size() method
car_price_df.groupby('transmission_type').size()
# Out:
# transmission_type
# AUTOMATED_MANUAL     626
# AUTOMATIC           8266
# DIRECT_DRIVE          68
# MANUAL              2935
# UNKNOWN               19
# dtype: int64

# %%
## Another way of doing the samething
car_price_df.describe(include=["O"])
# Out:
#              make           model transmission_type vehicle_style
# count       11914           11914             11914         11914
# unique         48             915                 5            16
# top     Chevrolet  Silverado 1500         AUTOMATIC         Sedan
# freq         1123             156              8266          3048

# %% [markdown]
# ## Question 2
# Create the correlation matrix for the numerical features of your dataset. In a correlation matrix, you compute the correlation coefficient between every pair of features in the dataset.
#
# What are the two features that have the biggest correlation in this dataset?

# %%
numeric_values = ['engine_hp', 'year', 'engine_cylinders',
'highway_mpg','city_mpg']

numerica_data_types = car_price_df.copy()

numerica_data_types = numerica_data_types[numeric_values]

# %%
numerica_data_types.describe()
# Out:
#           engine_hp          year  engine_cylinders   highway_mpg  \
# count  11914.000000  11914.000000      11914.000000  11914.000000
# mean     247.941749   2010.384338          5.614655     26.637485
# std      110.507669      7.579740          1.800554      8.863001
# min        0.000000   1990.000000          0.000000     12.000000
# 25%      170.000000   2007.000000          4.000000     22.000000
# 50%      225.000000   2015.000000          6.000000     26.000000
# 75%      300.000000   2016.000000          6.000000     30.000000
# max     1001.000000   2017.000000         16.000000    354.000000
#
#            city_mpg
# count  11914.000000
# mean      19.733255
# std        8.987798
# min        7.000000
# 25%       16.000000
# 50%       18.000000
# 75%       22.000000
# max      137.000000

# %%
## Calculate the correlation
corM = numerica_data_types.corr()

corM.unstack().sort_values(ascending = False)
# Out:
# engine_hp         engine_hp           1.000000
# year              year                1.000000
# highway_mpg       highway_mpg         1.000000
# engine_cylinders  engine_cylinders    1.000000
# city_mpg          city_mpg            1.000000
#                   highway_mpg         0.886829
# highway_mpg       city_mpg            0.886829
# engine_cylinders  engine_hp           0.774851
# engine_hp         engine_cylinders    0.774851
#                   year                0.338714
# year              engine_hp           0.338714
#                   highway_mpg         0.258240
# highway_mpg       year                0.258240
# year              city_mpg            0.198171
# city_mpg          year                0.198171
# year              engine_cylinders   -0.040708
# engine_cylinders  year               -0.040708
# engine_hp         highway_mpg        -0.415707
# highway_mpg       engine_hp          -0.415707
# city_mpg          engine_hp          -0.424918
# engine_hp         city_mpg           -0.424918
# city_mpg          engine_cylinders   -0.587306
# engine_cylinders  city_mpg           -0.587306
# highway_mpg       engine_cylinders   -0.614541
# engine_cylinders  highway_mpg        -0.614541
# dtype: float64

# %%
sns.heatmap(corM, annot=True)
# Out:
# <Axes: >

# %% [markdown]
# #### Make price binary
#
# Add a variable in the classification data to indicate if the price is above average or not

# %%
## Copy the data into a new variable for processing
classification_data = car_price_df.copy()

# %%
## Calculate the average price and use it to create a new variable 
average = classification_data['price'].mean()
classification_data['above_average'] = np.where(classification_data['price']>=average,1,0)

## drop the price variable to avoid bias the classification

del classification_data['price']

# %%
classification_data
# Out:
#           make       model  year  engine_hp  engine_cylinders  \
# 0          BMW  1 Series M  2011      335.0               6.0
# 1          BMW    1 Series  2011      300.0               6.0
# 2          BMW    1 Series  2011      300.0               6.0
# 3          BMW    1 Series  2011      230.0               6.0
# 4          BMW    1 Series  2011      230.0               6.0
# ...        ...         ...   ...        ...               ...
# 11909    Acura         ZDX  2012      300.0               6.0
# 11910    Acura         ZDX  2012      300.0               6.0
# 11911    Acura         ZDX  2012      300.0               6.0
# 11912    Acura         ZDX  2013      300.0               6.0
# 11913  Lincoln      Zephyr  2006      221.0               6.0
#
#       transmission_type  vehicle_style  highway_mpg  city_mpg  above_average
# 0                MANUAL          Coupe           26        19              1
# 1                MANUAL    Convertible           28        19              1
# 2                MANUAL          Coupe           28        20              0
# 3                MANUAL          Coupe           28        18              0
# 4                MANUAL    Convertible           28        18              0
# ...                 ...            ...          ...       ...            ...
# 11909         AUTOMATIC  4dr Hatchback           23        16              1
# 11910         AUTOMATIC  4dr Hatchback           23        16              1
# 11911         AUTOMATIC  4dr Hatchback           23        16              1
# 11912         AUTOMATIC  4dr Hatchback           23        16              1
# 11913         AUTOMATIC          Sedan           26        17              0
#
# [11914 rows x 10 columns]

# %% [markdown]
# #### Split the data
# Split the data into training, test and validation (60%,20%,20%) respectively
#
#
# - Split your data in train/val/test sets, with 60%/20%/20% distribution
# - Use Scikit-Learn for that (the train_test_split function) and set the seed to 42
# - Make sure that the target value (price) is not in your dataframe
#   - Price alerady drop above
